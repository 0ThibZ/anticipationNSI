# %% [markdown]
# # Module 1 : Les bases absolues de la programmation 🚀
#
# Bienvenue dans votre premier *Notebook Jupyter* ! Ce document est interactif : vous pouvez lire du texte (comme ici) et **exécuter du vrai code Python** dans les cases grises en dessous.
#
# Pour exécuter une cellule de code, cliquez dessus puis appuyez sur **Majuscule + Entrée** (Shift + Enter).

# %% [markdown]
# ## 1. L'affichage : La fonction `print()`
#
# En programmation, on a souvent besoin que l'ordinateur nous parle. On utilise pour cela la commande `print()`.

# %%
# Exécutez cette cellule !
print("Bienvenue dans l'aventure des Tours de Hanoï !")

# %% [markdown]
# ## 2. Les Variables 📦
#
# Une variable est comme une boîte dans laquelle on range une information (un nombre, du texte, etc.) pour s'en resservir plus tard.
# Pour le jeu des Tours de Hanoï, nous allons avoir besoin de savoir combien de disques nous utilisons.

# %%
nombre_de_disques = 3
nom_du_jeu = "Tours de Hanoï"

print("Nous allons jouer aux", nom_du_jeu, "avec", nombre_de_disques, "disques.")

# %% [markdown]
# ## 3. Les Mathématiques 🧮
#
# Python est aussi une excellente calculatrice. Vous pouvez utiliser `+` (addition), `-` (soustraction), `*` (multiplication), `/` (division), et `**` (puissance).

# %%
n = 3
coups_minimum = (2 ** n) - 1
print("Pour", n, "disques, il faut au minimum", coups_minimum, "coups pour gagner.")

# %% [markdown]
# ## 🤸 Exercice d'échauffement : Manipulation de texte et Modulo
#
# 1. **Le Texte** : Vous pouvez coller deux textes ensemble avec `+`. C'est la concaténation.
# 2. **Le Modulo (`%`)** : Il donne le reste d'une division. Par exemple `10 % 2` vaut `0` (10 est pair), et `11 % 2` vaut `1` (11 est impair).
#
# **À faire :** Complétez le code ci-dessous pour créer votre message de salutation, et calculez le reste de 15 divisé par 4.

# %%
prenom = "Alice"
message = "Bonjour " + prenom + " !"
print(message)

# À vous : calculez le modulo de 15 par 4
reste = 15 % 4
print("Le reste de 15 divisé par 4 est :", reste)

# %% [markdown]
# ## 🎯 Objectif Hanoï
#
# Dans la cellule ci-dessous, créez une variable `mes_disques` contenant la valeur `5`.
# Ensuite, calculez le nombre de coups minimum pour 5 disques et rangez le résultat dans une variable nommée `mon_calcul`.

# %%
# Écrivez votre code ici :
mes_disques = ...
mon_calcul = ...

# %% [markdown]
# ## 🧩 Exercice 1 : Les f-strings (★☆☆)
#
# Les **f-strings** sont une façon plus moderne et lisible de formater du texte.
# On les écrit avec un `f` devant les guillemets, et on met les variables entre `{}`.
#
# ```python
# n = 3
# print(f"Pour {n} disques, il faut {2**n - 1} coups.")
# ```
#
# **À faire :** Créez une variable `votre_nom` avec votre prénom, et une variable `n` avec la valeur `4`.
# Affichez avec une f-string : `"Bonjour [prénom] ! Pour 4 disques, il faut 15 coups."`

# %%
votre_nom = "..."   # Remplacez par votre prénom
n = 4

# Utilisez une f-string pour afficher le message
# print(f"Bonjour {votre_nom} ! Pour {n} disques, il faut {2**n - 1} coups.")

# %% [markdown]
# ## 🧩 Exercice 2 : Types de données et conversion (★★☆)
#
# En Python, chaque valeur a un **type** : `int` (entier), `str` (texte), `float` (décimal), `bool` (vrai/faux).
# La fonction `type()` permet de le découvrir.
#
# Parfois, une variable contient un nombre *sous forme de texte*. Il faut la **convertir** avec `int()` avant de calculer.
#
# **À faire :**
# 1. Vérifiez le type de `nb_disques_texte` avec `type()` et affichez-le.
# 2. Convertissez-la en entier avec `int()` et stockez le résultat dans `nb_disques`.
# 3. Calculez `coups = 2 ** nb_disques - 1` et affichez le résultat.

# %%
nb_disques_texte = "5"   # C'est un texte, pas un nombre !

# 1. Affichez le type de nb_disques_texte
print(type(nb_disques_texte))

# 2. Convertissez en entier
nb_disques = ...

# 3. Calculez et affichez les coups
coups = ...
print(f"Pour {nb_disques} disques : {coups} coups minimum.")

# %%
assert isinstance(nb_disques, int), "nb_disques doit être un entier (utilisez int() pour convertir) !"
assert coups == 31, "Pour 5 disques, il faut 31 coups (2**5 - 1) !"
print("✅ Exercice 2 validé !")

# %% [markdown]
# ## 🧩 Exercice 3 : La table des coups minimum (★★★)
#
# Sans utiliser de boucle (vous apprendrez ça au module 2 !), calculez manuellement le nombre de coups minimum pour chaque nombre de disques de 1 à 5.
# Stockez chaque résultat dans une variable nommée `coups_1`, `coups_2`, ..., `coups_5`.
#
# Observez le motif : chaque valeur vaut environ le double de la précédente plus 1. Pourquoi ?

# %%
coups_1 = ...   # Pour 1 disque
coups_2 = ...   # Pour 2 disques
coups_3 = ...   # Pour 3 disques
coups_4 = ...   # Pour 4 disques
coups_5 = ...   # Pour 5 disques

print(f"1 disque  → {coups_1} coup(s)")
print(f"2 disques → {coups_2} coup(s)")
print(f"3 disques → {coups_3} coup(s)")
print(f"4 disques → {coups_4} coup(s)")
print(f"5 disques → {coups_5} coup(s)")

# %%
assert coups_1 == 1, "Pour 1 disque, il faut 1 coup."
assert coups_2 == 3, "Pour 2 disques, il faut 3 coups."
assert coups_3 == 7, "Pour 3 disques, il faut 7 coups."
assert coups_4 == 15, "Pour 4 disques, il faut 15 coups."
assert coups_5 == 31, "Pour 5 disques, il faut 31 coups."
print("✅ Exercice 3 validé ! Vous avez découvert la formule 2^n - 1.")

# %% [markdown]
# ## 🧩 Exercice Bonus : Un programme interactif avec `input()` (★★☆)
#
# Jusqu'ici, les valeurs étaient fixées dans le code. Mais un vrai programme parle avec l'utilisateur !
#
# La fonction `input("message")` **affiche un message** et attend que l'utilisateur tape quelque chose.
# Elle retourne toujours du **texte** — pensez à convertir avec `int()` si vous avez besoin d'un nombre.
#
# ```python
# reponse = input("Quel est votre prénom ? ")
# print(f"Bonjour {reponse} !")
# ```
#
# **À faire :**
# 1. Demandez à l'utilisateur combien de disques il veut utiliser (entre 1 et 10).
# 2. Convertissez la réponse en entier.
# 3. Calculez et affichez le nombre de coups minimum avec une f-string.
#
# > **Note :** Dans Jupyter, une cellule avec `input()` attend votre saisie dans la barre qui apparaît en haut. Appuyez sur Entrée pour valider.

# %%
# Demandez le nombre de disques à l'utilisateur
nb_disques = int(input("Combien de disques voulez-vous ? (1-10) : "))

# Calculez le nombre de coups minimum
coups_min = 2 ** nb_disques - 1

print(f"Avec {nb_disques} disque(s), il faut au minimum {coups_min} coup(s) pour gagner.")
print(f"C'est {coups_min} fois que vous devrez déplacer un disque !")

# %% [markdown]
# ### ✅ Validation
#
# Exécutez la cellule ci-dessous pour vérifier si vous avez réussi.

# %%
assert mes_disques == 5, "La variable mes_disques doit valoir 5 !"
assert mon_calcul == 31, "Le calcul de mon_calcul est incorrect. Souvenez-vous : 2 ** mes_disques - 1"
print("🎉 Félicitations, vous avez validé le premier module !")

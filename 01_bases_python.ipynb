# %% [markdown]
# # Module 1 : Les bases absolues de la programmation 🚀
#
# Bienvenue dans votre premier *Notebook Jupyter* ! Ce document est interactif : vous pouvez lire du texte (comme ici) et **exécuter du vrai code Python** dans les cases grises en dessous.
#
# Pour exécuter une cellule de code, cliquez dessus puis appuyez sur **Majuscule + Entrée** (Shift + Enter).

# %% [markdown]
# ## 1. L'affichage : La fonction `print()`
#
# En programmation, on a souvent besoin que l'ordinateur nous parle. On utilise pour cela la commande `print()`.

# %%
# Exécutez cette cellule !
print("Bienvenue dans l'aventure des Tours de Hanoï !")

# %% [markdown]
# ## 2. Les Variables 📦
#
# Une variable est comme une boîte dans laquelle on range une information (un nombre, du texte, etc.) pour s'en resservir plus tard.
# Pour le jeu des Tours de Hanoï, nous allons avoir besoin de savoir combien de disques nous utilisons.

# %%
nombre_de_disques = 3
nom_du_jeu = "Tours de Hanoï"

print("Nous allons jouer aux", nom_du_jeu, "avec", nombre_de_disques, "disques.")

# %% [markdown]
# ## 3. Les Mathématiques 🧮
#
# Python est aussi une excellente calculatrice. Vous pouvez utiliser `+` (addition), `-` (soustraction), `*` (multiplication), `/` (division), et `**` (puissance).

# %%
n = 3
coups_minimum = (2 ** n) - 1
print("Pour", n, "disques, il faut au minimum", coups_minimum, "coups pour gagner.")

# %% [markdown]
# ## 🤸 Exercice d'échauffement : Manipulation de texte et Modulo
#
# 1. **Le Texte** : Vous pouvez coller deux textes ensemble avec `+`. C'est la concaténation.
# 2. **Le Modulo (`%`)** : Il donne le reste d'une division. Par exemple `10 % 2` vaut `0` (10 est pair), et `11 % 2` vaut `1` (11 est impair).
#
# **À faire :** Complétez le code ci-dessous pour créer votre message de salutation, et calculez le reste de 15 divisé par 4.

# %%
prenom = "Alice"
message = "Bonjour " + prenom + " !"
print(message)

# À vous : calculez le modulo de 15 par 4
reste = 15 % 4
print("Le reste de 15 divisé par 4 est :", reste)

# %% [markdown]
# ## 🎯 Objectif Hanoï
#
# Dans la cellule ci-dessous, créez une variable `mes_disques` contenant la valeur `5`.
# Ensuite, calculez le nombre de coups minimum pour 5 disques et rangez le résultat dans une variable nommée `mon_calcul`.

# %%
# Écrivez votre code ici :
mes_disques = ...
mon_calcul = ...

# %% [markdown]
# ### ✅ Validation
#
# Exécutez la cellule ci-dessous pour vérifier si vous avez réussi.

# %%
assert mes_disques == 5, "La variable mes_disques doit valoir 5 !"
assert mon_calcul == 31, "Le calcul de mon_calcul est incorrect. Souvenez-vous : 2 ** mes_disques - 1"
print("🎉 Félicitations, vous avez validé le premier module !")
